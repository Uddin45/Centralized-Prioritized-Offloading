# %%
print('Hello')
# Out:
# Hello

# %%
# Define the file paths
print('Hello start')
file_path_1 = 'C:\\Users\\uddin81\\Documents\\Customize_RL_MEC Env\\Deadline_Test\\MEC_RL_user50_DLine_60_90\\dqn_agent.py'
file_path_2 =  'C:\\Users\\uddin81\\Documents\\Customize_RL_MEC Env\\Backup_Retest\\dqn_agent.py'

# Open and read the files
with open(file_path_1, 'r') as file1, open(file_path_2, 'r') as file2:
    file1_lines = file1.readlines()
    file2_lines = file2.readlines()
count=0
# Compare the files line by line
for line_number, (line1, line2) in enumerate(zip(file1_lines, file2_lines), start=1):
    count+=1
    if line1 != line2:
        print(f"Difference at line {line_number}:\nFile 1: {line1}File 2: {line2}")
    else: 
        print('Hello ok')
        
print(count)
# Out:
# Hello start
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# Hello ok
# ...
