# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
window_size =250  # Define the window size


df_dqnp_16e9 = pd.read_csv('data_dqnp_16e9.csv', skiprows=1, names=['dqnp_epi_scores','dqnp_epi_task','dqnp_epi_energy','dqnp_epi_latency','dqnp_epi_num_task','dqnp_epi_task_P1','dqnp_epi_task_P2','dqnp_epi_task_P3',
                     'dqnp_epi_latency_P1','dqnp_epi_latency_P2','dqnp_epi_latency_P3','dqnp_epi_energy_P1','dqnp_epi_energy_P2','dqnp_epi_energy_P3','dqnp_epi_num_task_P1',
                     'dqnp_epi_num_task_P2','dqnp_epi_num_task_P3','dqnp_epi_datasize','dqnp_epi_datasize_P1','dqnp_epi_datasize_P2',
                     'dqnp_epi_datasize_P3','dqnp_epi_task_select_P1','dqnp_epi_task_select_P2','dqnp_epi_task_select_P3',\
                    'dqnp_epi_tran_latency_P1','dqnp_epi_tran_latency_P2','dqnp_epi_tran_latency_P3',\
                    'dqnp_epi_comp_latency_P1','dqnp_epi_comp_latency_P2','dqnp_epi_comp_latency_P3'])
df_dqnp_8e9 = pd.read_csv('data_dqnp_8e9.csv', skiprows=1, names=['dqnp_epi_scores','dqnp_epi_task','dqnp_epi_energy','dqnp_epi_latency','dqnp_epi_num_task','dqnp_epi_task_P1','dqnp_epi_task_P2','dqnp_epi_task_P3',
                     'dqnp_epi_latency_P1','dqnp_epi_latency_P2','dqnp_epi_latency_P3','dqnp_epi_energy_P1','dqnp_epi_energy_P2','dqnp_epi_energy_P3','dqnp_epi_num_task_P1',
                     'dqnp_epi_num_task_P2','dqnp_epi_num_task_P3','dqnp_epi_datasize','dqnp_epi_datasize_P1','dqnp_epi_datasize_P2',
                     'dqnp_epi_datasize_P3','dqnp_epi_task_select_P1','dqnp_epi_task_select_P2','dqnp_epi_task_select_P3',\
                    'dqnp_epi_tran_latency_P1','dqnp_epi_tran_latency_P2','dqnp_epi_tran_latency_P3',\
                    'dqnp_epi_comp_latency_P1','dqnp_epi_comp_latency_P2','dqnp_epi_comp_latency_P3'])

df_dqnp_4e9=  pd.read_csv('data_dqnp_4e9.csv', skiprows=1, names=['dqnp_epi_scores','dqnp_epi_task','dqnp_epi_energy','dqnp_epi_latency','dqnp_epi_num_task','dqnp_epi_task_P1','dqnp_epi_task_P2','dqnp_epi_task_P3',
                     'dqnp_epi_latency_P1','dqnp_epi_latency_P2','dqnp_epi_latency_P3','dqnp_epi_energy_P1','dqnp_epi_energy_P2','dqnp_epi_energy_P3','dqnp_epi_num_task_P1',
                     'dqnp_epi_num_task_P2','dqnp_epi_num_task_P3','dqnp_epi_datasize','dqnp_epi_datasize_P1','dqnp_epi_datasize_P2',
                     'dqnp_epi_datasize_P3','dqnp_epi_task_select_P1','dqnp_epi_task_select_P2','dqnp_epi_task_select_P3',\
                    'dqnp_epi_tran_latency_P1','dqnp_epi_tran_latency_P2','dqnp_epi_tran_latency_P3',\
                    'dqnp_epi_comp_latency_P1','dqnp_epi_comp_latency_P2','dqnp_epi_comp_latency_P3'])
df_dqnp_2e9=  pd.read_csv('data_dqnp_2e9.csv', skiprows=1, names=['dqnp_epi_scores','dqnp_epi_task','dqnp_epi_energy','dqnp_epi_latency','dqnp_epi_num_task','dqnp_epi_task_P1','dqnp_epi_task_P2','dqnp_epi_task_P3',
                     'dqnp_epi_latency_P1','dqnp_epi_latency_P2','dqnp_epi_latency_P3','dqnp_epi_energy_P1','dqnp_epi_energy_P2','dqnp_epi_energy_P3','dqnp_epi_num_task_P1',
                     'dqnp_epi_num_task_P2','dqnp_epi_num_task_P3','dqnp_epi_datasize','dqnp_epi_datasize_P1','dqnp_epi_datasize_P2',
                     'dqnp_epi_datasize_P3','dqnp_epi_task_select_P1','dqnp_epi_task_select_P2','dqnp_epi_task_select_P3',\
                    'dqnp_epi_tran_latency_P1','dqnp_epi_tran_latency_P2','dqnp_epi_tran_latency_P3',\
                    'dqnp_epi_comp_latency_P1','dqnp_epi_comp_latency_P2','dqnp_epi_comp_latency_P3'])

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
window_size =250  # Define the window size


df_dqnb_16e9 = pd.read_csv('data_dqnb_16e9.csv', skiprows=1, names=['dqnb_epi_scores','dqnb_epi_task','dqnb_epi_energy','dqnb_epi_latency','dqnb_epi_num_task','dqnb_epi_task_P1','dqnb_epi_task_P2','dqnb_epi_task_P3',
                     'dqnb_epi_latency_P1','dqnb_epi_latency_P2','dqnb_epi_latency_P3','dqnb_epi_energy_P1','dqnb_epi_energy_P2','dqnb_epi_energy_P3','dqnb_epi_num_task_P1',
                     'dqnb_epi_num_task_P2','dqnb_epi_num_task_P3','dqnb_epi_datasize','dqnb_epi_datasize_P1','dqnb_epi_datasize_P2',
                     'dqnb_epi_datasize_P3','dqnb_epi_task_select_P1','dqnb_epi_task_select_P2','dqnb_epi_task_select_P3',\
                    'dqnb_epi_tran_latency_P1','dqnb_epi_tran_latency_P2','dqnb_epi_tran_latency_P3',\
                    'dqnb_epi_comp_latency_P1','dqnb_epi_comp_latency_P2','dqnb_epi_comp_latency_P3'])
df_dqnb_8e9 = pd.read_csv('data_dqnb_8e9.csv', skiprows=1, names=['dqnb_epi_scores','dqnb_epi_task','dqnb_epi_energy','dqnb_epi_latency','dqnb_epi_num_task','dqnb_epi_task_P1','dqnb_epi_task_P2','dqnb_epi_task_P3',
                     'dqnb_epi_latency_P1','dqnb_epi_latency_P2','dqnb_epi_latency_P3','dqnb_epi_energy_P1','dqnb_epi_energy_P2','dqnb_epi_energy_P3','dqnb_epi_num_task_P1',
                     'dqnb_epi_num_task_P2','dqnb_epi_num_task_P3','dqnb_epi_datasize','dqnb_epi_datasize_P1','dqnb_epi_datasize_P2',
                     'dqnb_epi_datasize_P3','dqnb_epi_task_select_P1','dqnb_epi_task_select_P2','dqnb_epi_task_select_P3',\
                    'dqnb_epi_tran_latency_P1','dqnb_epi_tran_latency_P2','dqnb_epi_tran_latency_P3',\
                    'dqnb_epi_comp_latency_P1','dqnb_epi_comp_latency_P2','dqnb_epi_comp_latency_P3'])

df_dqnb_4e9=  pd.read_csv('data_dqnb_4e9.csv', skiprows=1, names=['dqnb_epi_scores','dqnb_epi_task','dqnb_epi_energy','dqnb_epi_latency','dqnb_epi_num_task','dqnb_epi_task_P1','dqnb_epi_task_P2','dqnb_epi_task_P3',
                     'dqnb_epi_latency_P1','dqnb_epi_latency_P2','dqnb_epi_latency_P3','dqnb_epi_energy_P1','dqnb_epi_energy_P2','dqnb_epi_energy_P3','dqnb_epi_num_task_P1',
                     'dqnb_epi_num_task_P2','dqnb_epi_num_task_P3','dqnb_epi_datasize','dqnb_epi_datasize_P1','dqnb_epi_datasize_P2',
                     'dqnb_epi_datasize_P3','dqnb_epi_task_select_P1','dqnb_epi_task_select_P2','dqnb_epi_task_select_P3',\
                    'dqnb_epi_tran_latency_P1','dqnb_epi_tran_latency_P2','dqnb_epi_tran_latency_P3',\
                    'dqnb_epi_comp_latency_P1','dqnb_epi_comp_latency_P2','dqnb_epi_comp_latency_P3'])
df_dqnb_2e9=  pd.read_csv('data_dqnb_2e9.csv', skiprows=1, names=['dqnb_epi_scores','dqnb_epi_task','dqnb_epi_energy','dqnb_epi_latency','dqnb_epi_num_task','dqnb_epi_task_P1','dqnb_epi_task_P2','dqnb_epi_task_P3',
                     'dqnb_epi_latency_P1','dqnb_epi_latency_P2','dqnb_epi_latency_P3','dqnb_epi_energy_P1','dqnb_epi_energy_P2','dqnb_epi_energy_P3','dqnb_epi_num_task_P1',
                     'dqnb_epi_num_task_P2','dqnb_epi_num_task_P3','dqnb_epi_datasize','dqnb_epi_datasize_P1','dqnb_epi_datasize_P2',
                     'dqnb_epi_datasize_P3','dqnb_epi_task_select_P1','dqnb_epi_task_select_P2','dqnb_epi_task_select_P3',\
                    'dqnb_epi_tran_latency_P1','dqnb_epi_tran_latency_P2','dqnb_epi_tran_latency_P3',\
                    'dqnb_epi_comp_latency_P1','dqnb_epi_comp_latency_P2','dqnb_epi_comp_latency_P3'])

# %%
total_done_P1=np.array(df_dqnp_2e9['dqnp_epi_task_select_P1'])*np.array(df_dqnp_2e9['dqnp_epi_task_P1'])
total_done_P2=np.array(df_dqnp_2e9['dqnp_epi_task_select_P2'])*np.array(df_dqnp_2e9['dqnp_epi_task_P2'])

total_done_P3=np.array(df_dqnp_2e9['dqnp_epi_task_select_P3'])*np.array(df_dqnp_2e9['dqnp_epi_task_P3'])

dqnp_2e9_epi_tran_latency=(total_done_P1*np.array(df_dqnp_2e9['dqnp_epi_tran_latency_P1'])+\
                           total_done_P2*np.array(df_dqnp_2e9['dqnp_epi_tran_latency_P2'])+\
                           total_done_P3*np.array(df_dqnp_2e9['dqnp_epi_tran_latency_P3']))/(total_done_P1+total_done_P2+total_done_P3)
total_done_P1=np.array(df_dqnp_4e9['dqnp_epi_task_select_P1'])*np.array(df_dqnp_4e9['dqnp_epi_task_P1'])
total_done_P2=np.array(df_dqnp_4e9['dqnp_epi_task_select_P2'])*np.array(df_dqnp_4e9['dqnp_epi_task_P2'])

total_done_P3=np.array(df_dqnp_4e9['dqnp_epi_task_select_P3'])*np.array(df_dqnp_4e9['dqnp_epi_task_P3'])

dqnp_4e9_epi_tran_latency=(total_done_P1*np.array(df_dqnp_4e9['dqnp_epi_tran_latency_P1'])+\
                           total_done_P2*np.array(df_dqnp_4e9['dqnp_epi_tran_latency_P2'])+\
                           total_done_P3*np.array(df_dqnp_4e9['dqnp_epi_tran_latency_P3']))/(total_done_P1+total_done_P2+total_done_P3)

total_done_P1=np.array(df_dqnp_8e9['dqnp_epi_task_select_P1'])*np.array(df_dqnp_8e9['dqnp_epi_task_P1'])
total_done_P2=np.array(df_dqnp_8e9['dqnp_epi_task_select_P2'])*np.array(df_dqnp_8e9['dqnp_epi_task_P2'])

total_done_P3=np.array(df_dqnp_8e9['dqnp_epi_task_select_P3'])*np.array(df_dqnp_8e9['dqnp_epi_task_P3'])

dqnp_8e9_epi_tran_latency=(total_done_P1*np.array(df_dqnp_8e9['dqnp_epi_tran_latency_P1'])+\
                           total_done_P2*np.array(df_dqnp_8e9['dqnp_epi_tran_latency_P2'])+\
                           total_done_P3*np.array(df_dqnp_8e9['dqnp_epi_tran_latency_P3']))/(total_done_P1+total_done_P2+total_done_P3)
total_done_P1=np.array(df_dqnp_16e9['dqnp_epi_task_select_P1'])*np.array(df_dqnp_16e9['dqnp_epi_task_P1'])
total_done_P2=np.array(df_dqnp_16e9['dqnp_epi_task_select_P2'])*np.array(df_dqnp_16e9['dqnp_epi_task_P2'])

total_done_P3=np.array(df_dqnp_16e9['dqnp_epi_task_select_P3'])*np.array(df_dqnp_16e9['dqnp_epi_task_P3'])

dqnp_16e9_epi_tran_latency=(total_done_P1*np.array(df_dqnp_16e9['dqnp_epi_tran_latency_P1'])+\
                           total_done_P2*np.array(df_dqnp_16e9['dqnp_epi_tran_latency_P2'])+\
                           total_done_P3*np.array(df_dqnp_16e9['dqnp_epi_tran_latency_P3']))/(total_done_P1+total_done_P2+total_done_P3)

data21=[np.mean(dqnp_2e9_epi_tran_latency[-window_size:]),np.mean(dqnp_4e9_epi_tran_latency[-window_size:]),np.mean(dqnp_8e9_epi_tran_latency[-window_size:]),np.mean(dqnp_16e9_epi_tran_latency[-window_size:])] 
print(data21)
# Out:
# [0.02513636330260456, 0.032216982826864284, 0.03792620825775322, 0.04054142353059181]

# %%
total_done_P1=np.array(df_dqnb_2e9['dqnb_epi_task_select_P1'])*np.array(df_dqnb_2e9['dqnb_epi_task_P1'])
total_done_P2=np.array(df_dqnb_2e9['dqnb_epi_task_select_P2'])*np.array(df_dqnb_2e9['dqnb_epi_task_P2'])

total_done_P3=np.array(df_dqnb_2e9['dqnb_epi_task_select_P3'])*np.array(df_dqnb_2e9['dqnb_epi_task_P3'])

dqnb_2e9_epi_tran_latency=(total_done_P1*np.array(df_dqnb_2e9['dqnb_epi_tran_latency_P1'])+\
                           total_done_P2*np.array(df_dqnb_2e9['dqnb_epi_tran_latency_P2'])+\
                           total_done_P3*np.array(df_dqnb_2e9['dqnb_epi_tran_latency_P3']))/(total_done_P1+total_done_P2+total_done_P3)
total_done_P1=np.array(df_dqnb_4e9['dqnb_epi_task_select_P1'])*np.array(df_dqnb_4e9['dqnb_epi_task_P1'])
total_done_P2=np.array(df_dqnb_4e9['dqnb_epi_task_select_P2'])*np.array(df_dqnb_4e9['dqnb_epi_task_P2'])

total_done_P3=np.array(df_dqnb_4e9['dqnb_epi_task_select_P3'])*np.array(df_dqnb_4e9['dqnb_epi_task_P3'])

dqnb_4e9_epi_tran_latency=(total_done_P1*np.array(df_dqnb_4e9['dqnb_epi_tran_latency_P1'])+\
                           total_done_P2*np.array(df_dqnb_4e9['dqnb_epi_tran_latency_P2'])+\
                           total_done_P3*np.array(df_dqnb_4e9['dqnb_epi_tran_latency_P3']))/(total_done_P1+total_done_P2+total_done_P3)

total_done_P1=np.array(df_dqnb_8e9['dqnb_epi_task_select_P1'])*np.array(df_dqnb_8e9['dqnb_epi_task_P1'])
total_done_P2=np.array(df_dqnb_8e9['dqnb_epi_task_select_P2'])*np.array(df_dqnb_8e9['dqnb_epi_task_P2'])

total_done_P3=np.array(df_dqnb_8e9['dqnb_epi_task_select_P3'])*np.array(df_dqnb_8e9['dqnb_epi_task_P3'])

dqnb_8e9_epi_tran_latency=(total_done_P1*np.array(df_dqnb_8e9['dqnb_epi_tran_latency_P1'])+\
                           total_done_P2*np.array(df_dqnb_8e9['dqnb_epi_tran_latency_P2'])+\
                           total_done_P3*np.array(df_dqnb_8e9['dqnb_epi_tran_latency_P3']))/(total_done_P1+total_done_P2+total_done_P3)
total_done_P1=np.array(df_dqnb_16e9['dqnb_epi_task_select_P1'])*np.array(df_dqnb_16e9['dqnb_epi_task_P1'])
total_done_P2=np.array(df_dqnb_16e9['dqnb_epi_task_select_P2'])*np.array(df_dqnb_16e9['dqnb_epi_task_P2'])

total_done_P3=np.array(df_dqnb_16e9['dqnb_epi_task_select_P3'])*np.array(df_dqnb_16e9['dqnb_epi_task_P3'])

dqnb_16e9_epi_tran_latency=(total_done_P1*np.array(df_dqnb_16e9['dqnb_epi_tran_latency_P1'])+\
                           total_done_P2*np.array(df_dqnb_16e9['dqnb_epi_tran_latency_P2'])+\
                           total_done_P3*np.array(df_dqnb_16e9['dqnb_epi_tran_latency_P3']))/(total_done_P1+total_done_P2+total_done_P3)

data22=[np.mean(dqnb_2e9_epi_tran_latency[-window_size:]),np.mean(dqnb_4e9_epi_tran_latency[-window_size:]),np.mean(dqnb_8e9_epi_tran_latency[-window_size:]),np.mean(dqnb_16e9_epi_tran_latency[-window_size:])] 
print(data22)
# Out:
# [0.022903003395390104, 0.029613174958750925, 0.03555089763836264, 0.03838760039921664]

# %%
total_done_P1=np.array(df_dqnp_2e9['dqnp_epi_task_select_P1'])*np.array(df_dqnp_2e9['dqnp_epi_task_P1'])
total_done_P2=np.array(df_dqnp_2e9['dqnp_epi_task_select_P2'])*np.array(df_dqnp_2e9['dqnp_epi_task_P2'])

total_done_P3=np.array(df_dqnp_2e9['dqnp_epi_task_select_P3'])*np.array(df_dqnp_2e9['dqnp_epi_task_P3'])

dqnp_2e9_epi_comp_latency=(total_done_P1*np.array(df_dqnp_2e9['dqnp_epi_comp_latency_P1'])+\
                           total_done_P2*np.array(df_dqnp_2e9['dqnp_epi_comp_latency_P2'])+\
                           total_done_P3*np.array(df_dqnp_2e9['dqnp_epi_comp_latency_P3']))/(total_done_P1+total_done_P2+total_done_P3)
total_done_P1=np.array(df_dqnp_4e9['dqnp_epi_task_select_P1'])*np.array(df_dqnp_4e9['dqnp_epi_task_P1'])
total_done_P2=np.array(df_dqnp_4e9['dqnp_epi_task_select_P2'])*np.array(df_dqnp_4e9['dqnp_epi_task_P2'])

total_done_P3=np.array(df_dqnp_4e9['dqnp_epi_task_select_P3'])*np.array(df_dqnp_4e9['dqnp_epi_task_P3'])

dqnp_4e9_epi_comp_latency=(total_done_P1*np.array(df_dqnp_4e9['dqnp_epi_comp_latency_P1'])+\
                           total_done_P2*np.array(df_dqnp_4e9['dqnp_epi_comp_latency_P2'])+\
                           total_done_P3*np.array(df_dqnp_4e9['dqnp_epi_comp_latency_P3']))/(total_done_P1+total_done_P2+total_done_P3)

total_done_P1=np.array(df_dqnp_8e9['dqnp_epi_task_select_P1'])*np.array(df_dqnp_8e9['dqnp_epi_task_P1'])
total_done_P2=np.array(df_dqnp_8e9['dqnp_epi_task_select_P2'])*np.array(df_dqnp_8e9['dqnp_epi_task_P2'])

total_done_P3=np.array(df_dqnp_8e9['dqnp_epi_task_select_P3'])*np.array(df_dqnp_8e9['dqnp_epi_task_P3'])

dqnp_8e9_epi_comp_latency=(total_done_P1*np.array(df_dqnp_8e9['dqnp_epi_comp_latency_P1'])+\
                           total_done_P2*np.array(df_dqnp_8e9['dqnp_epi_comp_latency_P2'])+\
                           total_done_P3*np.array(df_dqnp_8e9['dqnp_epi_comp_latency_P3']))/(total_done_P1+total_done_P2+total_done_P3)
total_done_P1=np.array(df_dqnp_16e9['dqnp_epi_task_select_P1'])*np.array(df_dqnp_16e9['dqnp_epi_task_P1'])
total_done_P2=np.array(df_dqnp_16e9['dqnp_epi_task_select_P2'])*np.array(df_dqnp_16e9['dqnp_epi_task_P2'])

total_done_P3=np.array(df_dqnp_16e9['dqnp_epi_task_select_P3'])*np.array(df_dqnp_16e9['dqnp_epi_task_P3'])

dqnp_16e9_epi_comp_latency=(total_done_P1*np.array(df_dqnp_16e9['dqnp_epi_comp_latency_P1'])+\
                           total_done_P2*np.array(df_dqnp_16e9['dqnp_epi_comp_latency_P2'])+\
                           total_done_P3*np.array(df_dqnp_16e9['dqnp_epi_comp_latency_P3']))/(total_done_P1+total_done_P2+total_done_P3)

data23=[np.mean(dqnp_2e9_epi_comp_latency[-window_size:]),np.mean(dqnp_4e9_epi_comp_latency[-window_size:]),np.mean(dqnp_8e9_epi_comp_latency[-window_size:]),np.mean(dqnp_16e9_epi_comp_latency[-window_size:])] 
print(data23)
# Out:
# [0.08200562630370911, 0.05403468236656532, 0.026461580668211155, 0.013341740720358443]

# %%
total_done_P1=np.array(df_dqnb_2e9['dqnb_epi_task_select_P1'])*np.array(df_dqnb_2e9['dqnb_epi_task_P1'])
total_done_P2=np.array(df_dqnb_2e9['dqnb_epi_task_select_P2'])*np.array(df_dqnb_2e9['dqnb_epi_task_P2'])

total_done_P3=np.array(df_dqnb_2e9['dqnb_epi_task_select_P3'])*np.array(df_dqnb_2e9['dqnb_epi_task_P3'])

dqnb_2e9_epi_comp_latency=(total_done_P1*np.array(df_dqnb_2e9['dqnb_epi_comp_latency_P1'])+\
                           total_done_P2*np.array(df_dqnb_2e9['dqnb_epi_comp_latency_P2'])+\
                           total_done_P3*np.array(df_dqnb_2e9['dqnb_epi_comp_latency_P3']))/(total_done_P1+total_done_P2+total_done_P3)
total_done_P1=np.array(df_dqnb_4e9['dqnb_epi_task_select_P1'])*np.array(df_dqnb_4e9['dqnb_epi_task_P1'])
total_done_P2=np.array(df_dqnb_4e9['dqnb_epi_task_select_P2'])*np.array(df_dqnb_4e9['dqnb_epi_task_P2'])

total_done_P3=np.array(df_dqnb_4e9['dqnb_epi_task_select_P3'])*np.array(df_dqnb_4e9['dqnb_epi_task_P3'])

dqnb_4e9_epi_comp_latency=(total_done_P1*np.array(df_dqnb_4e9['dqnb_epi_comp_latency_P1'])+\
                           total_done_P2*np.array(df_dqnb_4e9['dqnb_epi_comp_latency_P2'])+\
                           total_done_P3*np.array(df_dqnb_4e9['dqnb_epi_comp_latency_P3']))/(total_done_P1+total_done_P2+total_done_P3)

total_done_P1=np.array(df_dqnb_8e9['dqnb_epi_task_select_P1'])*np.array(df_dqnb_8e9['dqnb_epi_task_P1'])
total_done_P2=np.array(df_dqnb_8e9['dqnb_epi_task_select_P2'])*np.array(df_dqnb_8e9['dqnb_epi_task_P2'])

total_done_P3=np.array(df_dqnb_8e9['dqnb_epi_task_select_P3'])*np.array(df_dqnb_8e9['dqnb_epi_task_P3'])

dqnb_8e9_epi_comp_latency=(total_done_P1*np.array(df_dqnb_8e9['dqnb_epi_comp_latency_P1'])+\
                           total_done_P2*np.array(df_dqnb_8e9['dqnb_epi_comp_latency_P2'])+\
                           total_done_P3*np.array(df_dqnb_8e9['dqnb_epi_comp_latency_P3']))/(total_done_P1+total_done_P2+total_done_P3)
total_done_P1=np.array(df_dqnb_16e9['dqnb_epi_task_select_P1'])*np.array(df_dqnb_16e9['dqnb_epi_task_P1'])
total_done_P2=np.array(df_dqnb_16e9['dqnb_epi_task_select_P2'])*np.array(df_dqnb_16e9['dqnb_epi_task_P2'])

total_done_P3=np.array(df_dqnb_16e9['dqnb_epi_task_select_P3'])*np.array(df_dqnb_16e9['dqnb_epi_task_P3'])

dqnb_16e9_epi_comp_latency=(total_done_P1*np.array(df_dqnb_16e9['dqnb_epi_comp_latency_P1'])+\
                           total_done_P2*np.array(df_dqnb_16e9['dqnb_epi_comp_latency_P2'])+\
                           total_done_P3*np.array(df_dqnb_16e9['dqnb_epi_comp_latency_P3']))/(total_done_P1+total_done_P2+total_done_P3)

data24=[np.mean(dqnb_2e9_epi_comp_latency[-window_size:]),np.mean(dqnb_4e9_epi_comp_latency[-window_size:]),np.mean(dqnb_8e9_epi_comp_latency[-window_size:]),np.mean(dqnb_16e9_epi_comp_latency[-window_size:])] 
print(data24)
# Out:
# [0.08093705519533913, 0.056834685794241016, 0.02747520116751103, 0.013896798270213092]

# %%
import matplotlib.pyplot as plt

window_size =250  # Define the window size
dqnp_2e9_epi_task=df_dqnp_2e9['dqnp_epi_task']
dqnp_2e9_epi_task_P1=df_dqnp_2e9['dqnp_epi_task_P1']
dqnp_2e9_epi_task_P2=df_dqnp_2e9['dqnp_epi_task_P2']
dqnp_2e9_epi_task_P3=df_dqnp_2e9['dqnp_epi_task_P3']

dqnp_4e9_epi_task=df_dqnp_4e9['dqnp_epi_task']
dqnp_4e9_epi_task_P1=df_dqnp_4e9['dqnp_epi_task_P1']
dqnp_4e9_epi_task_P2=df_dqnp_4e9['dqnp_epi_task_P2']
dqnp_4e9_epi_task_P3=df_dqnp_4e9['dqnp_epi_task_P3']

dqnp_8e9_epi_task=df_dqnp_8e9['dqnp_epi_task']
dqnp_8e9_epi_task_P1=df_dqnp_8e9['dqnp_epi_task_P1']
dqnp_8e9_epi_task_P2=df_dqnp_8e9['dqnp_epi_task_P2']
dqnp_8e9_epi_task_P3=df_dqnp_8e9['dqnp_epi_task_P3']

dqnp_16e9_epi_task=df_dqnp_16e9['dqnp_epi_task']
dqnp_16e9_epi_task_P1=df_dqnp_16e9['dqnp_epi_task_P1']
dqnp_16e9_epi_task_P2=df_dqnp_16e9['dqnp_epi_task_P2']
dqnp_16e9_epi_task_P3=df_dqnp_16e9['dqnp_epi_task_P3']

dqnb_2e9_epi_task=df_dqnb_2e9['dqnb_epi_task']
dqnb_2e9_epi_task_P1=df_dqnb_2e9['dqnb_epi_task_P1']
dqnb_2e9_epi_task_P2=df_dqnb_2e9['dqnb_epi_task_P2']
dqnb_2e9_epi_task_P3=df_dqnb_2e9['dqnb_epi_task_P3']

dqnb_4e9_epi_task=df_dqnb_4e9['dqnb_epi_task']
dqnb_4e9_epi_task_P1=df_dqnb_4e9['dqnb_epi_task_P1']
dqnb_4e9_epi_task_P2=df_dqnb_4e9['dqnb_epi_task_P2']
dqnb_4e9_epi_task_P3=df_dqnb_4e9['dqnb_epi_task_P3']

dqnb_8e9_epi_task=df_dqnb_8e9['dqnb_epi_task']
dqnb_8e9_epi_task_P1=df_dqnb_8e9['dqnb_epi_task_P1']
dqnb_8e9_epi_task_P2=df_dqnb_8e9['dqnb_epi_task_P2']
dqnb_8e9_epi_task_P3=df_dqnb_8e9['dqnb_epi_task_P3']

dqnb_16e9_epi_task=df_dqnb_16e9['dqnb_epi_task']
dqnb_16e9_epi_task_P1=df_dqnb_16e9['dqnb_epi_task_P1']
dqnb_16e9_epi_task_P2=df_dqnb_16e9['dqnb_epi_task_P2']
dqnb_16e9_epi_task_P3=df_dqnb_16e9['dqnb_epi_task_P3']

data1=[sum(dqnp_2e9_epi_task[-window_size:]) / window_size,sum(dqnp_4e9_epi_task[-window_size:]) / window_size,sum(dqnp_8e9_epi_task[-window_size:]) / window_size,\
      sum(dqnp_16e9_epi_task[-window_size:]) / window_size]
data2=[sum(dqnp_2e9_epi_task_P1[-window_size:]) / window_size,sum(dqnp_4e9_epi_task_P1[-window_size:]) / window_size,sum(dqnp_8e9_epi_task_P1[-window_size:]) / window_size,\
      sum(dqnp_16e9_epi_task_P1[-window_size:]) / window_size]
data3=[sum(dqnp_2e9_epi_task_P2[-window_size:]) / window_size,sum(dqnp_4e9_epi_task_P2[-window_size:]) / window_size,sum(dqnp_8e9_epi_task_P2[-window_size:]) / window_size,\
      sum(dqnp_16e9_epi_task_P2[-window_size:]) / window_size]
data4=[sum(dqnp_2e9_epi_task_P3[-window_size:]) / window_size,sum(dqnp_4e9_epi_task_P3[-window_size:]) / window_size,sum(dqnp_8e9_epi_task_P3[-window_size:]) / window_size,\
      sum(dqnp_16e9_epi_task_P3[-window_size:]) / window_size]

data5=[sum(dqnb_2e9_epi_task[-window_size:]) / window_size,sum(dqnb_4e9_epi_task[-window_size:]) / window_size,sum(dqnb_8e9_epi_task[-window_size:]) / window_size,\
      sum(dqnb_16e9_epi_task[-window_size:]) / window_size]
data6=[sum(dqnb_2e9_epi_task_P1[-window_size:]) / window_size,sum(dqnb_4e9_epi_task_P1[-window_size:]) / window_size,sum(dqnb_8e9_epi_task_P1[-window_size:]) / window_size,\
      sum(dqnb_16e9_epi_task_P1[-window_size:]) / window_size]
data7=[sum(dqnb_2e9_epi_task_P2[-window_size:]) / window_size,sum(dqnb_4e9_epi_task_P2[-window_size:]) / window_size,sum(dqnb_8e9_epi_task_P2[-window_size:]) / window_size,\
      sum(dqnb_16e9_epi_task_P2[-window_size:]) / window_size]
data8=[sum(dqnb_2e9_epi_task_P3[-window_size:]) / window_size,sum(dqnb_4e9_epi_task_P3[-window_size:]) / window_size,sum(dqnb_8e9_epi_task_P3[-window_size:]) / window_size,\
      sum(dqnb_16e9_epi_task_P3[-window_size:]) / window_size]


data = [data1, data2, data3,data4,data5, data6, data7,data8]
Legend = ['overall_dqnp','task done_P1_dqnp', 'task done_P2_dqnp', 'task done_P3_dqnp',\
         'overall_dqnb','task done_P1_dqnb', 'task done_P2_dqnb', 'task done_P3_dqnb']

params = ['2','4', '8', '16']

fig, ax = plt.subplots()
for i, system_data in enumerate(data):
    ax.plot(params, system_data, marker='o', linewidth=2, label=f'{Legend[i]}')

ax.set_xlabel('Frequency')
ax.set_ylabel('Average task')
ax.set_title('Task Done Comparison Across Different Frequency')

ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()
print("'overall_dqnp','task done_P1_dqnp', 'task done_P2_dqnp', 'task done_P3_dqnp',\
         'overall_dqnb','task done_P1_dqnb', 'task done_P2_dqnb', 'task done_P3_dqnb'", data)
# Out:
# 'overall_dqnp','task done_P1_dqnp', 'task done_P2_dqnp', 'task done_P3_dqnp',         'overall_dqnb','task done_P1_dqnb', 'task done_P2_dqnb', 'task done_P3_dqnb' [[0.6397559999999999, 0.7919520000000002, 0.8432800000000005, 0.8602000000000003], [0.6671358071989666, 0.8058035613101068, 0.8519158991523931, 0.8725879900707366], [0.6412523050211949, 0.7952847458036376, 0.8455847652140838, 0.8621879926935296], [0.6109294985383574, 0.7767875409199907, 0.8344910062172703, 0.8501164175309532], [0.5541840000000001, 0.6687800000000004, 0.7095879999999993, 0.7226880000000002], [0.5693304316140364, 0.6763483066614339, 0.7170257979611004, 0.7295903241058062], [0.5454227374008225, 0.6654687875976417, 0.7058521068037674, 0.7191528250379331], [0.5136271698494891, 0.6435282477154392, 0.6874346235625485, 0.7031792121341033]]

# %%
dqnp_16e9_epi_latency=df_dqnp_16e9['dqnp_epi_latency']
dqnp_16e9_epi_latency_P1=df_dqnp_16e9['dqnp_epi_latency_P1']
dqnp_16e9_epi_latency_P2=df_dqnp_16e9['dqnp_epi_latency_P2']
dqnp_16e9_epi_latency_P3=df_dqnp_16e9['dqnp_epi_latency_P3']

dqnp_16e9_epi_tran_latency_P1=df_dqnp_16e9['dqnp_epi_tran_latency_P1']
dqnp_16e9_epi_tran_latency_P2=df_dqnp_16e9['dqnp_epi_tran_latency_P2']
dqnp_16e9_epi_tran_latency_P3=df_dqnp_16e9['dqnp_epi_tran_latency_P3']
dqnp_16e9_epi_comp_latency_P1=df_dqnp_16e9['dqnp_epi_comp_latency_P1']
dqnp_16e9_epi_comp_latency_P2=df_dqnp_16e9['dqnp_epi_comp_latency_P2']
dqnp_16e9_epi_comp_latency_P3=df_dqnp_16e9['dqnp_epi_comp_latency_P3']
dqnp_8e9_epi_latency=df_dqnp_8e9['dqnp_epi_latency']
dqnp_8e9_epi_latency_P1=df_dqnp_8e9['dqnp_epi_latency_P1']
dqnp_8e9_epi_latency_P2=df_dqnp_8e9['dqnp_epi_latency_P2']
dqnp_8e9_epi_latency_P3=df_dqnp_8e9['dqnp_epi_latency_P3']
dqnp_8e9_epi_tran_latency_P1=df_dqnp_8e9['dqnp_epi_tran_latency_P1']
dqnp_8e9_epi_tran_latency_P2=df_dqnp_8e9['dqnp_epi_tran_latency_P2']
dqnp_8e9_epi_tran_latency_P3=df_dqnp_8e9['dqnp_epi_tran_latency_P3']
dqnp_8e9_epi_comp_latency_P1=df_dqnp_8e9['dqnp_epi_comp_latency_P1']
dqnp_8e9_epi_comp_latency_P2=df_dqnp_8e9['dqnp_epi_comp_latency_P2']
dqnp_8e9_epi_comp_latency_P3=df_dqnp_8e9['dqnp_epi_comp_latency_P3']

dqnp_4e9_epi_latency=df_dqnp_4e9['dqnp_epi_latency']
dqnp_4e9_epi_latency_P1=df_dqnp_4e9['dqnp_epi_latency_P1']
dqnp_4e9_epi_latency_P2=df_dqnp_4e9['dqnp_epi_latency_P2']
dqnp_4e9_epi_latency_P3=df_dqnp_4e9['dqnp_epi_latency_P3']
dqnp_4e9_epi_tran_latency_P1=df_dqnp_4e9['dqnp_epi_tran_latency_P1']
dqnp_4e9_epi_tran_latency_P2=df_dqnp_4e9['dqnp_epi_tran_latency_P2']
dqnp_4e9_epi_tran_latency_P3=df_dqnp_4e9['dqnp_epi_tran_latency_P3']
dqnp_4e9_epi_comp_latency_P1=df_dqnp_4e9['dqnp_epi_comp_latency_P1']
dqnp_4e9_epi_comp_latency_P2=df_dqnp_4e9['dqnp_epi_comp_latency_P2']
dqnp_4e9_epi_comp_latency_P3=df_dqnp_4e9['dqnp_epi_comp_latency_P3']

dqnp_2e9_epi_latency=df_dqnp_2e9['dqnp_epi_latency']
dqnp_2e9_epi_latency_P1=df_dqnp_2e9['dqnp_epi_latency_P1']
dqnp_2e9_epi_latency_P2=df_dqnp_2e9['dqnp_epi_latency_P2']
dqnp_2e9_epi_latency_P3=df_dqnp_2e9['dqnp_epi_latency_P3']
dqnp_2e9_epi_tran_latency_P1=df_dqnp_2e9['dqnp_epi_tran_latency_P1']
dqnp_2e9_epi_tran_latency_P2=df_dqnp_2e9['dqnp_epi_tran_latency_P2']
dqnp_2e9_epi_tran_latency_P3=df_dqnp_2e9['dqnp_epi_tran_latency_P3']
dqnp_2e9_epi_comp_latency_P1=df_dqnp_2e9['dqnp_epi_comp_latency_P1']
dqnp_2e9_epi_comp_latency_P2=df_dqnp_2e9['dqnp_epi_comp_latency_P2']
dqnp_2e9_epi_comp_latency_P3=df_dqnp_2e9['dqnp_epi_comp_latency_P3']





data1=[sum(dqnp_2e9_epi_latency[-window_size:]) / window_size,sum(dqnp_4e9_epi_latency[-window_size:]) / window_size,sum(dqnp_8e9_epi_latency[-window_size:]) / window_size,\
      sum(dqnp_16e9_epi_latency[-window_size:]) / window_size]
data2=[sum(dqnp_2e9_epi_latency_P1[-window_size:]) / window_size,sum(dqnp_4e9_epi_latency_P1[-window_size:]) / window_size,sum(dqnp_8e9_epi_latency_P1[-window_size:]) / window_size,\
      sum(dqnp_16e9_epi_latency_P1[-window_size:]) / window_size]
data3=[sum(dqnp_2e9_epi_latency_P2[-window_size:]) / window_size,sum(dqnp_4e9_epi_latency_P2[-window_size:]) / window_size,sum(dqnp_8e9_epi_latency_P2[-window_size:]) / window_size,\
      sum(dqnp_16e9_epi_latency_P2[-window_size:]) / window_size]
data4=[sum(dqnp_2e9_epi_latency_P3[-window_size:]) / window_size,sum(dqnp_4e9_epi_latency_P3[-window_size:]) / window_size,sum(dqnp_8e9_epi_latency_P3[-window_size:]) / window_size,\
      sum(dqnp_16e9_epi_latency_P3[-window_size:]) / window_size]


data5=[sum(dqnp_2e9_epi_comp_latency_P1[-window_size:]) / window_size,sum(dqnp_4e9_epi_comp_latency_P1[-window_size:]) / window_size,sum(dqnp_8e9_epi_comp_latency_P1[-window_size:]) / window_size,\
      sum(dqnp_16e9_epi_comp_latency_P1[-window_size:]) / window_size]
data6=[sum(dqnp_2e9_epi_comp_latency_P2[-window_size:]) / window_size,sum(dqnp_4e9_epi_comp_latency_P2[-window_size:]) / window_size,sum(dqnp_8e9_epi_comp_latency_P2[-window_size:]) / window_size,\
      sum(dqnp_16e9_epi_comp_latency_P2[-window_size:]) / window_size]
data7=[sum(dqnp_2e9_epi_comp_latency_P3[-window_size:]) / window_size,sum(dqnp_4e9_epi_comp_latency_P3[-window_size:]) / window_size,sum(dqnp_8e9_epi_comp_latency_P3[-window_size:]) / window_size,\
      sum(dqnp_16e9_epi_comp_latency_P3[-window_size:]) / window_size]

data8=[sum(dqnp_2e9_epi_tran_latency_P1[-window_size:]) / window_size,sum(dqnp_4e9_epi_tran_latency_P1[-window_size:]) / window_size,sum(dqnp_8e9_epi_tran_latency_P1[-window_size:]) / window_size,\
      sum(dqnp_16e9_epi_tran_latency_P1[-window_size:]) / window_size]
data9=[sum(dqnp_2e9_epi_tran_latency_P2[-window_size:]) / window_size,sum(dqnp_4e9_epi_tran_latency_P2[-window_size:]) / window_size,sum(dqnp_8e9_epi_tran_latency_P2[-window_size:]) / window_size,\
      sum(dqnp_16e9_epi_tran_latency_P2[-window_size:]) / window_size]
data10=[sum(dqnp_2e9_epi_tran_latency_P3[-window_size:]) / window_size,sum(dqnp_4e9_epi_tran_latency_P3[-window_size:]) / window_size,sum(dqnp_8e9_epi_tran_latency_P3[-window_size:]) / window_size,\
      sum(dqnp_16e9_epi_tran_latency_P3[-window_size:]) / window_size]

# %%
dqnb_16e9_epi_latency=df_dqnb_16e9['dqnb_epi_latency']
dqnb_16e9_epi_latency_P1=df_dqnb_16e9['dqnb_epi_latency_P1']
dqnb_16e9_epi_latency_P2=df_dqnb_16e9['dqnb_epi_latency_P2']
dqnb_16e9_epi_latency_P3=df_dqnb_16e9['dqnb_epi_latency_P3']

dqnb_16e9_epi_tran_latency_P1=df_dqnb_16e9['dqnb_epi_tran_latency_P1']
dqnb_16e9_epi_tran_latency_P2=df_dqnb_16e9['dqnb_epi_tran_latency_P2']
dqnb_16e9_epi_tran_latency_P3=df_dqnb_16e9['dqnb_epi_tran_latency_P3']
dqnb_16e9_epi_comp_latency_P1=df_dqnb_16e9['dqnb_epi_comp_latency_P1']
dqnb_16e9_epi_comp_latency_P2=df_dqnb_16e9['dqnb_epi_comp_latency_P2']
dqnb_16e9_epi_comp_latency_P3=df_dqnb_16e9['dqnb_epi_comp_latency_P3']
dqnb_8e9_epi_latency=df_dqnb_8e9['dqnb_epi_latency']
dqnb_8e9_epi_latency_P1=df_dqnb_8e9['dqnb_epi_latency_P1']
dqnb_8e9_epi_latency_P2=df_dqnb_8e9['dqnb_epi_latency_P2']
dqnb_8e9_epi_latency_P3=df_dqnb_8e9['dqnb_epi_latency_P3']
dqnb_8e9_epi_tran_latency_P1=df_dqnb_8e9['dqnb_epi_tran_latency_P1']
dqnb_8e9_epi_tran_latency_P2=df_dqnb_8e9['dqnb_epi_tran_latency_P2']
dqnb_8e9_epi_tran_latency_P3=df_dqnb_8e9['dqnb_epi_tran_latency_P3']
dqnb_8e9_epi_comp_latency_P1=df_dqnb_8e9['dqnb_epi_comp_latency_P1']
dqnb_8e9_epi_comp_latency_P2=df_dqnb_8e9['dqnb_epi_comp_latency_P2']
dqnb_8e9_epi_comp_latency_P3=df_dqnb_8e9['dqnb_epi_comp_latency_P3']

dqnb_4e9_epi_latency=df_dqnb_4e9['dqnb_epi_latency']
dqnb_4e9_epi_latency_P1=df_dqnb_4e9['dqnb_epi_latency_P1']
dqnb_4e9_epi_latency_P2=df_dqnb_4e9['dqnb_epi_latency_P2']
dqnb_4e9_epi_latency_P3=df_dqnb_4e9['dqnb_epi_latency_P3']
dqnb_4e9_epi_tran_latency_P1=df_dqnb_4e9['dqnb_epi_tran_latency_P1']
dqnb_4e9_epi_tran_latency_P2=df_dqnb_4e9['dqnb_epi_tran_latency_P2']
dqnb_4e9_epi_tran_latency_P3=df_dqnb_4e9['dqnb_epi_tran_latency_P3']
dqnb_4e9_epi_comp_latency_P1=df_dqnb_4e9['dqnb_epi_comp_latency_P1']
dqnb_4e9_epi_comp_latency_P2=df_dqnb_4e9['dqnb_epi_comp_latency_P2']
dqnb_4e9_epi_comp_latency_P3=df_dqnb_4e9['dqnb_epi_comp_latency_P3']

dqnb_2e9_epi_latency=df_dqnb_2e9['dqnb_epi_latency']
dqnb_2e9_epi_latency_P1=df_dqnb_2e9['dqnb_epi_latency_P1']
dqnb_2e9_epi_latency_P2=df_dqnb_2e9['dqnb_epi_latency_P2']
dqnb_2e9_epi_latency_P3=df_dqnb_2e9['dqnb_epi_latency_P3']
dqnb_2e9_epi_tran_latency_P1=df_dqnb_2e9['dqnb_epi_tran_latency_P1']
dqnb_2e9_epi_tran_latency_P2=df_dqnb_2e9['dqnb_epi_tran_latency_P2']
dqnb_2e9_epi_tran_latency_P3=df_dqnb_2e9['dqnb_epi_tran_latency_P3']
dqnb_2e9_epi_comp_latency_P1=df_dqnb_2e9['dqnb_epi_comp_latency_P1']
dqnb_2e9_epi_comp_latency_P2=df_dqnb_2e9['dqnb_epi_comp_latency_P2']
dqnb_2e9_epi_comp_latency_P3=df_dqnb_2e9['dqnb_epi_comp_latency_P3']


data11=[sum(dqnb_2e9_epi_latency[-window_size:]) / window_size,sum(dqnb_4e9_epi_latency[-window_size:]) / window_size,sum(dqnb_8e9_epi_latency[-window_size:]) / window_size,\
      sum(dqnb_16e9_epi_latency[-window_size:]) / window_size]
data12=[sum(dqnb_2e9_epi_latency_P1[-window_size:]) / window_size,sum(dqnb_4e9_epi_latency_P1[-window_size:]) / window_size,sum(dqnb_8e9_epi_latency_P1[-window_size:]) / window_size,\
      sum(dqnb_16e9_epi_latency_P1[-window_size:]) / window_size]
data13=[sum(dqnb_2e9_epi_latency_P2[-window_size:]) / window_size,sum(dqnb_4e9_epi_latency_P2[-window_size:]) / window_size,sum(dqnb_8e9_epi_latency_P2[-window_size:]) / window_size,\
      sum(dqnb_16e9_epi_latency_P2[-window_size:]) / window_size]
data14=[sum(dqnb_2e9_epi_latency_P3[-window_size:]) / window_size,sum(dqnb_4e9_epi_latency_P3[-window_size:]) / window_size,sum(dqnb_8e9_epi_latency_P3[-window_size:]) / window_size,\
      sum(dqnb_16e9_epi_latency_P3[-window_size:]) / window_size]


data15=[sum(dqnb_2e9_epi_comp_latency_P1[-window_size:]) / window_size,sum(dqnb_4e9_epi_comp_latency_P1[-window_size:]) / window_size,sum(dqnb_8e9_epi_comp_latency_P1[-window_size:]) / window_size,\
      sum(dqnb_16e9_epi_comp_latency_P1[-window_size:]) / window_size]
data16=[sum(dqnb_2e9_epi_comp_latency_P2[-window_size:]) / window_size,sum(dqnb_4e9_epi_comp_latency_P2[-window_size:]) / window_size,sum(dqnb_8e9_epi_comp_latency_P2[-window_size:]) / window_size,\
      sum(dqnb_16e9_epi_comp_latency_P2[-window_size:]) / window_size]
data17=[sum(dqnb_2e9_epi_comp_latency_P3[-window_size:]) / window_size,sum(dqnb_4e9_epi_comp_latency_P3[-window_size:]) / window_size,sum(dqnb_8e9_epi_comp_latency_P3[-window_size:]) / window_size,\
      sum(dqnb_16e9_epi_comp_latency_P3[-window_size:]) / window_size]

data18=[sum(dqnb_2e9_epi_tran_latency_P1[-window_size:]) / window_size,sum(dqnb_4e9_epi_tran_latency_P1[-window_size:]) / window_size,sum(dqnb_8e9_epi_tran_latency_P1[-window_size:]) / window_size,\
      sum(dqnb_16e9_epi_tran_latency_P1[-window_size:]) / window_size]
data19=[sum(dqnb_2e9_epi_tran_latency_P2[-window_size:]) / window_size,sum(dqnb_4e9_epi_tran_latency_P2[-window_size:]) / window_size,sum(dqnb_8e9_epi_tran_latency_P2[-window_size:]) / window_size,\
      sum(dqnb_16e9_epi_tran_latency_P2[-window_size:]) / window_size]
data20=[sum(dqnb_2e9_epi_tran_latency_P3[-window_size:]) / window_size,sum(dqnb_4e9_epi_tran_latency_P3[-window_size:]) / window_size,sum(dqnb_8e9_epi_tran_latency_P3[-window_size:]) / window_size,\
      sum(dqnb_16e9_epi_tran_latency_P3[-window_size:]) / window_size]

# %%
import numpy as np

data = [data8,data9, data10,\
        data18,data19, data20]
data=np.array(data)*1000
Legend = ['tran_latency_P1_dqnp','tran_latency_P2_dqnp','tran_latency_P3_dqnp',\
          'tran_latency_P1_dqnb','tran_latency_P2_dqnb','tran_latency_P3_dqnb']

params = ['2','4', '8', '16']

fig, ax = plt.subplots()
for i, system_data in enumerate(data):
    ax.plot(params, system_data, marker='o', linewidth=2, label=f'{Legend[i]}')

ax.set_xlabel('Frequency')
ax.set_ylabel('Average Latency')
ax.set_title('Latency Comparison Across Different Frequency')

ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()
print("['dqnp_tran_latency_P1','dqnp_tran_latency_P2', 'dqnp_tran_latency_P3', \
          'dqnb_tran_latency_P1','dqnb_tran_latency_P2','dqnb_tran_latency_P3']", data)
# Out:
# ['dqnp_tran_latency_P1','dqnp_tran_latency_P2', 'dqnp_tran_latency_P3',           'dqnb_tran_latency_P1','dqnb_tran_latency_P2','dqnb_tran_latency_P3'] [[26.83482399 34.53317358 39.84651819 42.56147894]
#  [25.11251412 32.34863967 38.2163946  40.65293295]
#  [23.40880061 30.11605335 36.17358048 39.03891596]
#  [23.89382423 30.79445252 36.72054553 39.52060561]
#  [22.16699575 28.82948225 34.73680001 37.6429071 ]
#  [20.52252742 26.61369174 32.76729174 35.53186227]]

# %%
import numpy as np

data = [data5, data6, data7,\
        data15, data16, data17]
data=np.array(data)*1000
Legend = ['comp_latency_P1_dqnp','comp_latency_P2_dqnp', 'comp_latency_P3_dqnp', \
          
         'comp_latency_P1_dqnb','comp_latency_P2_dqnb', 'comp_latency_P3_dqnb']

params = ['2','4', '8', '16']

fig, ax = plt.subplots()
for i, system_data in enumerate(data):
    ax.plot(params, system_data, marker='o', linewidth=2, label=f'{Legend[i]}')

ax.set_xlabel('Frequency')
ax.set_ylabel('Average Latency')
ax.set_title('Latency Comparison Across Different Frequency')

ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()
print("['dqnp_comp_latency_P1','dqnp_comp_latency_P2', 'dqnp_comp_latency_P3', \
          'dqnb_comp_latency_P1','dqnb_comp_latency_P2','dqnb_comp_latency_P3']", data)
# Out:
# ['dqnp_comp_latency_P1','dqnp_comp_latency_P2', 'dqnp_comp_latency_P3',           'dqnb_comp_latency_P1','dqnb_comp_latency_P2','dqnb_comp_latency_P3'] [[85.81107751 54.5162813  26.72955098 13.41447862]
#  [81.99651403 54.29684693 26.51561285 13.35043114]
#  [78.01911367 53.38305779 26.21474338 13.28020001]
#  [82.09868443 56.9019609  27.46647577 13.90058284]
#  [80.07474223 56.78426971 27.490203   13.88923313]
#  [78.18353658 56.67480354 27.5032388  13.90846703]]

# %%
import numpy as np


data = [data1, data11,data21,data22,data23,data24]

Legend = ['latency_dqnp','latency_dqnb','tran_latency_dqnp','tran_latency_dqnb','comp_latency_dqnp','comp_latency_dqnb']

params = ['2','4', '8', '16']

fig, ax = plt.subplots()
for i, system_data in enumerate(data):
    ax.plot(params, system_data, marker='o', linewidth=2, label=f'{Legend[i]}')

ax.set_xlabel('Frequency')
ax.set_ylabel('Average Latency')
ax.set_title('Latency Comparison Across Different Frequency')

ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()
print("['latency_dqnp','latency_dqnb','tran_latency_dqnp','tran_latency_dqnb',\
        'comp_latency_dqnp','comp_latency_dqnb']", data)
# Out:
# ['latency_dqnp','latency_dqnb','tran_latency_dqnp','tran_latency_dqnb',        'comp_latency_dqnp','comp_latency_dqnb'] [[0.1071419896063138, 0.0862516651934297, 0.06438778892596445, 0.05388316425095033], [0.10384005859072938, 0.08644786075299202, 0.0630260988058737, 0.05228439866942973], [0.02513636330260456, 0.032216982826864284, 0.03792620825775322, 0.04054142353059181], [0.022903003395390104, 0.029613174958750925, 0.03555089763836264, 0.03838760039921664], [0.08200562630370911, 0.05403468236656532, 0.026461580668211155, 0.013341740720358443], [0.08093705519533913, 0.056834685794241016, 0.02747520116751103, 0.013896798270213092]]

# %%
import matplotlib.pyplot as plt

window_size =250  # Define the window size
dqnp_2e9_epi_energy_P1=df_dqnp_2e9['dqnp_epi_energy_P1']
dqnp_2e9_epi_energy_P2=df_dqnp_2e9['dqnp_epi_energy_P2']
dqnp_2e9_epi_energy_P3=df_dqnp_2e9['dqnp_epi_energy_P3']
dqnp_4e9_epi_energy_P1=df_dqnp_4e9['dqnp_epi_energy_P1']
dqnp_4e9_epi_energy_P2=df_dqnp_4e9['dqnp_epi_energy_P2']
dqnp_4e9_epi_energy_P3=df_dqnp_4e9['dqnp_epi_energy_P3']


dqnp_8e9_epi_energy_P1=df_dqnp_8e9['dqnp_epi_energy_P1']
dqnp_8e9_epi_energy_P2=df_dqnp_8e9['dqnp_epi_energy_P2']
dqnp_8e9_epi_energy_P3=df_dqnp_8e9['dqnp_epi_energy_P3']


dqnp_16e9_epi_energy_P1=df_dqnp_16e9['dqnp_epi_energy_P1']
dqnp_16e9_epi_energy_P2=df_dqnp_16e9['dqnp_epi_energy_P2']
dqnp_16e9_epi_energy_P3=df_dqnp_16e9['dqnp_epi_energy_P3']


data2=[sum(dqnp_2e9_epi_energy_P1[-window_size:]) / window_size,sum(dqnp_4e9_epi_energy_P1[-window_size:]) / window_size,sum(dqnp_8e9_epi_energy_P1[-window_size:]) / window_size,\
      sum(dqnp_16e9_epi_energy_P1[-window_size:]) / window_size]
data3=[sum(dqnp_2e9_epi_energy_P2[-window_size:]) / window_size,sum(dqnp_4e9_epi_energy_P2[-window_size:]) / window_size,sum(dqnp_8e9_epi_energy_P2[-window_size:]) / window_size,\
      sum(dqnp_16e9_epi_energy_P2[-window_size:]) / window_size]
data4=[sum(dqnp_2e9_epi_energy_P3[-window_size:]) / window_size,sum(dqnp_4e9_epi_energy_P3[-window_size:]) / window_size,sum(dqnp_8e9_epi_energy_P3[-window_size:]) / window_size,\
      sum(dqnp_16e9_epi_energy_P3[-window_size:]) / window_size]

data1=[data2[0]+data3[0]+data4[0],data2[1]+data3[1]+data4[1],data2[2]+data3[2]+data4[2],data2[3]+data3[3]+data4[3]]
      
data = [ data2, data3,data4]
Legend = ['comp_late_P1', 'comp_late_P2', 'comp_late_P3']

params = ['2','4', '8', '16']

fig, ax = plt.subplots()
for i, system_data in enumerate(data):
    ax.plot(params, system_data, marker='o', linewidth=2, label=f'{Legend[i]}')

ax.set_xlabel('Frequency')
ax.set_ylabel('Average energy')
ax.set_title('energy Comparison Across Different Frequency')

ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()
