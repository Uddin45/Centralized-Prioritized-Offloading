# %%
print('mean_task_P1_ratio_by_bucket_51_10_100', np.mean(bucket_tasks_mean[(26,35)]['P1_task_done_mean'][-window_size:]),
                  np.mean(bucket_tasks_mean[(35,45)]['P1_task_done_mean'][-window_size:]) , np.mean(bucket_tasks_mean[(45,55)]['P1_task_done_mean'][-window_size:])
                  ,np.mean(bucket_tasks_mean[(55,65)]['P1_task_done_mean'][-window_size:]), np.mean(bucket_tasks_mean[(65,75)]['P1_task_done_mean'][-window_size:]))
            print('mean_task_P2_ratio_by_bucket_51_10_100', np.mean(bucket_tasks_mean[(26,35)]['P2_task_done_mean'][-window_size:]),
                  np.mean(bucket_tasks_mean[(35,45)]['P2_task_done_mean'][-window_size:]) , np.mean(bucket_tasks_mean[(45,55)]['P2_task_done_mean'][-window_size:])
                  ,np.mean(bucket_tasks_mean[(55,65)]['P2_task_done_mean'][-window_size:]), np.mean(bucket_tasks_mean[(65,75)]['P2_task_done_mean'][-window_size:]))
            print('mean_task_P3_ratio_by_bucket_51_10_100', np.mean(bucket_tasks_mean[(26,35)]['P3_task_done_mean'][-window_size:]),
                  np.mean(bucket_tasks_mean[(35,45)]['P3_task_done_mean'][-window_size:]) , np.mean(bucket_tasks_mean[(45,55)]['P3_task_done_mean'][-window_size:])
                  ,np.mean(bucket_tasks_mean[(55,65)]['P3_task_done_mean'][-window_size:]), np.mean(bucket_tasks_mean[(65,75)]['P3_task_done_mean'][-window_size:]))
            print('mean_task_P1_select_by_bucket_51_10_100', np.mean(bucket_task_len[(26,35)]['P1_task_done_mean_len'][-window_size:]),
                  np.mean(bucket_task_len[(35,45)]['P1_task_done_mean_len'][-window_size:]) , np.mean(bucket_task_len[(45,55)]['P1_task_done_mean_len'][-window_size:])
                  ,np.mean(bucket_task_len[(55,65)]['P1_task_done_mean_len'][-window_size:]), np.mean(bucket_task_len[(65,75)]['P1_task_done_mean_len'][-window_size:]))
            print('mean_task_P2_select_by_bucket_51_10_100', np.mean(bucket_task_len[(26,35)]['P2_task_done_mean_len'][-window_size:]),
                  np.mean(bucket_task_len[(35,45)]['P2_task_done_mean_len'][-window_size:]) , np.mean(bucket_task_len[(45,55)]['P2_task_done_mean_len'][-window_size:])
                  ,np.mean(bucket_task_len[(55,65)]['P2_task_done_mean_len'][-window_size:]), np.mean(bucket_task_len[(65,75)]['P2_task_done_mean_len'][-window_size:]))
            print('mean_task_P3_select_by_bucket_51_10_100', np.mean(bucket_task_len[(26,35)]['P3_task_done_mean_len'][-window_size:]),
                  np.mean(bucket_task_len[(35,45)]['P3_task_done_mean_len'][-window_size:]) , np.mean(bucket_task_len[(45,55)]['P3_task_done_mean_len'][-window_size:])
                  ,np.mean(bucket_task_len[(55,65)]['P3_task_done_mean_len'][-window_size:]), np.mean(bucket_task_len[(65,75)]['P3_task_done_mean_len'][-window_size:]))

            print('mean_task_P1_latency_by_bucket_51_10_100', np.mean(bucket_latency_mean[(26,35)]['P1_latency_mean'][-window_size:]),
                  np.mean(bucket_latency_mean[(35,45)]['P1_latency_mean'][-window_size:]) , np.mean(bucket_latency_mean[(45,55)]['P1_latency_mean'][-window_size:])
                  ,np.mean(bucket_latency_mean[(55,65)]['P1_latency_mean'][-window_size:]), np.mean(bucket_latency_mean[(65,75)]['P1_latency_mean'][-window_size:]))
            print('mean_task_P2_latency_by_bucket_51_10_100', np.mean(bucket_latency_mean[(26,35)]['P2_latency_mean'][-window_size:]),
                  np.mean(bucket_latency_mean[(35,45)]['P2_latency_mean'][-window_size:]) , np.mean(bucket_latency_mean[(45,55)]['P2_latency_mean'][-window_size:])
                  ,np.mean(bucket_latency_mean[(55,65)]['P2_latency_mean'][-window_size:]), np.mean(bucket_latency_mean[(65,75)]['P2_latency_mean'][-window_size:]))
            print('mean_task_P3_latency_by_bucket_51_10_100', np.mean(bucket_latency_mean[(26,35)]['P3_latency_mean'][-window_size:]),
                  np.mean(bucket_latency_mean[(35,45)]['P3_latency_mean'][-window_size:]) , np.mean(bucket_latency_mean[(45,55)]['P3_latency_mean'][-window_size:])
                  ,np.mean(bucket_latency_mean[(55,65)]['P3_latency_mean'][-window_size:]), np.mean(bucket_latency_mean[(65,75)]['P3_latency_mean'][-window_size:]))
            
            print('mean_task_P1_energy_by_bucket_51_10_100', np.mean(bucket_energy_mean[(26,35)]['P1_energy_mean'][-window_size:]),
                  np.mean(bucket_energy_mean[(35,45)]['P1_energy_mean'][-window_size:]) , np.mean(bucket_energy_mean[(45,55)]['P1_energy_mean'][-window_size:])
                  ,np.mean(bucket_energy_mean[(55,65)]['P1_energy_mean'][-window_size:]), np.mean(bucket_energy_mean[(65,75)]['P1_energy_mean'][-window_size:]))
            print('mean_task_P2_energy_by_bucket_51_10_100', np.mean(bucket_energy_mean[(26,35)]['P2_energy_mean'][-window_size:]),
                  np.mean(bucket_energy_mean[(35,45)]['P2_energy_mean'][-window_size:]) , np.mean(bucket_energy_mean[(45,55)]['P2_energy_mean'][-window_size:])
                  ,np.mean(bucket_energy_mean[(55,65)]['P2_energy_mean'][-window_size:]), np.mean(bucket_energy_mean[(65,75)]['P2_energy_mean'][-window_size:]))
            print('mean_task_P3_energy_by_bucket_51_10_100', np.mean(bucket_energy_mean[(26,35)]['P3_energy_mean'][-window_size:]),
                  np.mean(bucket_energy_mean[(35,45)]['P3_energy_mean'][-window_size:]) , np.mean(bucket_energy_mean[(45,55)]['P3_energy_mean'][-window_size:])
                  ,np.mean(bucket_energy_mean[(55,65)]['P3_energy_mean'][-window_size:]), np.mean(bucket_energy_mean[(65,75)]['P3_energy_mean'][-window_size:]))
