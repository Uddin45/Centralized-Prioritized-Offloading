# %%
import numpy as np
freq=[2,4,8,16]
mean=[]
for i in range (1000):
    max_freq_server=[np.random.choice(freq)*1e9 for _ in range (3)]
    mean.append(np.mean(max_freq_server))
print(np.mean(mean))
# Out:
# 7381333333.333334
